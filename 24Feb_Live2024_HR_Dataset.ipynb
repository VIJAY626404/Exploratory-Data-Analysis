# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("HRDataset_v14.csv")

# %%
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID
# 0         Adinolfi, Wilson  K  10026          0                0         1  \
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
df.shape
# Out:
# (311, 36)

# %%
df.sort_values('EmpID',ascending=True, inplace=True)

# %%
df
# Out:
#            Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID
# 36        Candie, Calvin  10001          0                0         1  \
# 5      Anderson, Linda    10002          0                0         0
# 22         Billis, Helen  10003          1                1         0
# 174       Lynch, Lindsay  10004          0                0         0
# 212     Patronick, Lucas  10005          0                0         1
# ..                   ...    ...        ...              ...       ...
# 267   Stansfield, Norman  10307          1                1         1
# 90   Fernandes, Nilson    10308          1                1         1
# 91            Fett, Boba  10309          0                0         1
# 69       Desimone, Carl   10310          1                1         1
# 64            Dee, Randy  10311          1                1         1
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...
# ...

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
# How to move Ahead
df = pd.read_csv("HRDataset_v14.csv",index_col = ["Employee_Name"])

# %%
df
# Out:
#                           EmpID  MarriedID  MaritalStatusID  GenderID
# Employee_Name
# Adinolfi, Wilson  K       10026          0                0         1  \
# Ait Sidi, Karthikeyan     10084          1                1         1
# Akinkuolie, Sarah         10196          1                1         0
# Alagbe,Trina              10088          1                1         0
# Anderson, Carol           10069          0                2         0
# ...                         ...        ...              ...       ...
# Woodson, Jason            10135          0                0         1
# Ybarra, Catherine         10301          0                0         0
# Zamora, Jennifer          10010          0                0         0
# Zhou, Julia               10043          0                0         0
# Zima, Colleen             10271          0                4         0
#
#                           EmpStatusID  DeptID  PerfScoreID
# Employee_Name
# ...

# %%
df.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID
# count    311.000000  311.000000       311.000000  311.000000   311.000000  \
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary
# count  311.000000   311.000000              311.000000     311.000000  \
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
# 25% salary of employee is <=55501

# %%
df.isnull().sum()
# Out:
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ManagerID                       8
# ...

# %%
# 'DateofTermination' columns have 207 null value

# %%
df['DateofTermination']
# Out:
# Employee_Name
# Adinolfi, Wilson  K               NaN
# Ait Sidi, Karthikeyan       6/16/2016
# Akinkuolie, Sarah           9/24/2012
# Alagbe,Trina                      NaN
# Anderson, Carol              9/6/2016
#                               ...
# Woodson, Jason                    NaN
# Ybarra, Catherine           9/29/2015
# Zamora, Jennifer                  NaN
# Zhou, Julia                       NaN
# Zima, Colleen                     NaN
# Name: DateofTermination, Length: 311, dtype: object

# %%
df.fillna("0",inplace=True)

# %%
df.isnull().sum()
# Out:
# EmpID                         0
# MarriedID                     0
# MaritalStatusID               0
# GenderID                      0
# EmpStatusID                   0
# DeptID                        0
# PerfScoreID                   0
# FromDiversityJobFairID        0
# Salary                        0
# Termd                         0
# PositionID                    0
# Position                      0
# State                         0
# Zip                           0
# DOB                           0
# Sex                           0
# MaritalDesc                   0
# CitizenDesc                   0
# HispanicLatino                0
# RaceDesc                      0
# DateofHire                    0
# DateofTermination             0
# TermReason                    0
# EmploymentStatus              0
# Department                    0
# ManagerName                   0
# ManagerID                     0
# RecruitmentSource             0
# PerformanceScore              0
# ...

# %%
# there have no null value in above columns

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                           EmpID  MarriedID  MaritalStatusID  GenderID
# Employee_Name
# Adinolfi, Wilson  K       10026          0                0         1  \
# Ait Sidi, Karthikeyan     10084          1                1         1
# Akinkuolie, Sarah         10196          1                1         0
# Alagbe,Trina              10088          1                1         0
# Anderson, Carol           10069          0                2         0
# ...                         ...        ...              ...       ...
# Woodson, Jason            10135          0                0         1
# Ybarra, Catherine         10301          0                0         0
# Zamora, Jennifer          10010          0                0         0
# Zhou, Julia               10043          0                0         0
# Zima, Colleen             10271          0                4         0
#
#                           EmpStatusID  DeptID  PerfScoreID
# Employee_Name
# ...

# %% [markdown]
# # name of employees with highest salary >> Top 10

# %%
df.Salary.sort_values(ascending=False).head(10)
# Out:
# Employee_Name
# King, Janet         250000
# Zamora, Jennifer    220450
# Houlihan, Debra     180000
# Foss, Jason         178000
# Corleone, Vito      170500
# Monroe, Peter       157000
# Roper, Katie        150290
# Ruiz, Ricardo       148999
# Roup,Simon          140920
# Dougall, Eric       138888
# Name: Salary, dtype: int64

# %% [markdown]
# # i want to know people who need special attention

# %%
df['PerformanceScore']
# Out:
# Employee_Name
# Adinolfi, Wilson  K             Exceeds
# Ait Sidi, Karthikeyan       Fully Meets
# Akinkuolie, Sarah           Fully Meets
# Alagbe,Trina                Fully Meets
# Anderson, Carol             Fully Meets
#                                ...
# Woodson, Jason              Fully Meets
# Ybarra, Catherine                   PIP
# Zamora, Jennifer                Exceeds
# Zhou, Julia                 Fully Meets
# Zima, Colleen               Fully Meets
# Name: PerformanceScore, Length: 311, dtype: object

# %%
df['PerformanceScore'].unique()
# PIP--> performance improvment plan
# Out:
# array(['Exceeds', 'Fully Meets', 'Needs Improvement', 'PIP'], dtype=object)

# %%
# how are those employee who are in PIP

# %%
a = df[df.PerformanceScore=='PIP']

# %%
list(a.index)
# Out:
# ['Delarge, Alex',
#  'Desimone, Carl ',
#  'Dietrich, Jenna  ',
#  'Erilus, Angela',
#  'Fernandes, Nilson  ',
#  'Fett, Boba',
#  'Forrest, Alex',
#  'Gonzalez, Juan',
#  'Miller, Ned',
#  "O'hare, Lynn",
#  'Sparks, Taylor  ',
#  'Stansfield, Norman',
#  'Ybarra, Catherine ']

# %%
len(list(a.index))
# there 13 employee who need special attention
# Out:
# 13

# %%
df['Absences']
# Out:
# Employee_Name
# Adinolfi, Wilson  K          1
# Ait Sidi, Karthikeyan       17
# Akinkuolie, Sarah            3
# Alagbe,Trina                15
# Anderson, Carol              2
#                             ..
# Woodson, Jason              13
# Ybarra, Catherine            4
# Zamora, Jennifer            16
# Zhou, Julia                 11
# Zima, Colleen                2
# Name: Absences, Length: 311, dtype: int64

# %%
df['Absences'].value_counts()
# Out:
# Absences
# 4     23
# 16    23
# 7     21
# 2     21
# 15    20
# 13    17
# 14    17
# 3     16
# 19    16
# 6     16
# 11    15
# 17    15
# 1     14
# 20    14
# 9     14
# 5     12
# 8     11
# 10    10
# 12     8
# 18     8
# Name: count, dtype: int64

# %%
# insights : 20 employee have take 14days absences

# %%
# based on marridID
df['MarriedID'].value_counts()
# Out:
# MarriedID
# 0    187
# 1    124
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID', 'EmpStatusID',
#        'DeptID', 'PerfScoreID', 'FromDiversityJobFairID', 'Salary', 'Termd',
#        'PositionID', 'Position', 'State', 'Zip', 'DOB', 'Sex', 'MaritalDesc',
#        'CitizenDesc', 'HispanicLatino', 'RaceDesc', 'DateofHire',
#        'DateofTermination', 'TermReason', 'EmploymentStatus', 'Department',
#        'ManagerName', 'ManagerID', 'RecruitmentSource', 'PerformanceScore',
#        'EngagementSurvey', 'EmpSatisfaction', 'SpecialProjectsCount',
#        'LastPerformanceReview_Date', 'DaysLateLast30', 'Absences'],
#       dtype='object')

# %%
df[df['SpecialProjectsCount']!=0]
# Out:
#                           EmpID  MarriedID  MaritalStatusID  GenderID
# Employee_Name
# Ait Sidi, Karthikeyan     10084          1                1         1  \
# Andreola, Colby           10194          0                0         0
# Bacong, Alejandro         10250          0                2         1
# Barbossa, Hector          10012          0                2         1
# Becker, Renee             10245          0                0         0
# ...                         ...        ...              ...       ...
# Voldemort, Lord           10118          1                1         1
# Wang, Charlie             10172          0                0         1
# Warfield, Sarah           10127          0                4         0
# Zamora, Jennifer          10010          0                0         0
# Zhou, Julia               10043          0                0         0
#
#                           EmpStatusID  DeptID  PerfScoreID
# Employee_Name
# ...

# %%
spl_project = df[df['SpecialProjectsCount']!=0]

# %%
spl_project['SpecialProjectsCount'].sort_values(ascending=False)
# Out:
# Employee_Name
# Warfield, Sarah      8
# Daniele, Ann         8
# Le, Binh             7
# Champaigne, Brian    7
# Petrowsky, Thelma    7
#                     ..
# Dee, Randy           3
# Patronick, Lucas     3
# Boutwell, Bonalyn    3
# Foster-Baker, Amy    2
# Sparks, Taylor       1
# Name: SpecialProjectsCount, Length: 70, dtype: int64

# %%
# 70 people have special projects counts
# these are high performing employee

# %% [markdown]
# # i want to know which are the  employee have top 10 highest and top 10 lowest salary.

# %%
# compare top 10 highest and lowest salary
plt = [1,2,3,45,6,7,8,9,10]
x = df['Salary'].sort_values(ascending=False).head(10)
y = df['Salary'].sort_values(ascending=False).tail(10)



plt.bar(c,x,color='g',label="highest_salary")
plt.bar(c,y,color='r',label="lowest_salary")
plt.title('Top 10 Highest and Lowest compresion',fontsize=15)

plt.xticks(c)
plt.ylabel(salaries)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 8
#       3 x = df['Salary'].sort_values(ascending=False).head(10)
#       4 y = df['Salary'].sort_values(ascending=False).tail(10)
# ----> 8 plt.bar(c,x,color='g',label="highest_salary")
#       9 plt.bar(c,y,color='r',label="lowest_salary")
#      10 plt.title('Top 10 Highest and Lowest compresion',fontsize=15)
#
# AttributeError: 'list' object has no attribute 'bar'

# %%
x
# Out:
# Employee_Name
# King, Janet         250000
# Zamora, Jennifer    220450
# Houlihan, Debra     180000
# Foss, Jason         178000
# Corleone, Vito      170500
# Monroe, Peter       157000
# Roper, Katie        150290
# Ruiz, Ricardo       148999
# Roup,Simon          140920
# Dougall, Eric       138888
# Name: Salary, dtype: int64

# %%
y
# Out:
# Employee_Name
# Purinton, Janine       46430
# Sadki, Nore            46428
# Dobrin, Denisa  S      46335
# Langton, Enrico        46120
# Perry, Shakira         45998
# Kirill, Alexandra      45433
# Mahoney, Lauren        45395
# Rhoads, Thomas         45115
# Jacobi, Hannah         45069
# Zima, Colleen          45046
# Name: Salary, dtype: int64

# %% [markdown]
# # Know the Recuiterment Source

# %%
df['RecruitmentSource']
# Out:
# Employee_Name
# Adinolfi, Wilson  K                  LinkedIn
# Ait Sidi, Karthikeyan                  Indeed
# Akinkuolie, Sarah                    LinkedIn
# Alagbe,Trina                           Indeed
# Anderson, Carol                 Google Search
#                                   ...
# Woodson, Jason                       LinkedIn
# Ybarra, Catherine               Google Search
# Zamora, Jennifer            Employee Referral
# Zhou, Julia                 Employee Referral
# Zima, Colleen                        LinkedIn
# Name: RecruitmentSource, Length: 311, dtype: object

# %%
df['RecruitmentSource'].value_counts()
# Out:
# RecruitmentSource
# Indeed                     87
# LinkedIn                   76
# Google Search              49
# Employee Referral          31
# Diversity Job Fair         29
# CareerBuilder              23
# Website                    13
# Other                       2
# On-line Web application     1
# Name: count, dtype: int64

# %%
df['RecruitmentSource'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
z = df.PerformanceScore.value_counts()
z
# Out:
# PerformanceScore
# Fully Meets          243
# Exceeds               37
# Needs Improvement     18
# PIP                   13
# Name: count, dtype: int64

# %%
sns.lineplot(data=z,marker='o',color='purple',linewidth=2)
# some type of trend analysis
# Out:
# <Axes: xlabel='PerformanceScore', ylabel='count'>

# %% [markdown]
# # Satisfaction of employees

# %%
b= df.EmpSatisfaction.value_counts()

# %%
plt.s

# %%
plt.stem(b.index,b)
plt.title('Emp Satisfaction')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 plt.stem(b.index,b)
#       2 plt.title('Emp Satisfaction')
#
# AttributeError: 'list' object has no attribute 'stem'

# %%
# on on avg 100, 3 rating

# %%
df.columns
# Out:
# Index(['EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID', 'EmpStatusID',
#        'DeptID', 'PerfScoreID', 'FromDiversityJobFairID', 'Salary', 'Termd',
#        'PositionID', 'Position', 'State', 'Zip', 'DOB', 'Sex', 'MaritalDesc',
#        'CitizenDesc', 'HispanicLatino', 'RaceDesc', 'DateofHire',
#        'DateofTermination', 'TermReason', 'EmploymentStatus', 'Department',
#        'ManagerName', 'ManagerID', 'RecruitmentSource', 'PerformanceScore',
#        'EngagementSurvey', 'EmpSatisfaction', 'SpecialProjectsCount',
#        'LastPerformanceReview_Date', 'DaysLateLast30', 'Absences'],
#       dtype='object')

# %% [markdown]
# # Multivariate analysis

# %%
numerical_columns = ['Salary','EmpSatisfaction','SpecialProjectsCount','EngagementSurvey','DaysLateLast30','Absences']

# %%
sns.pairplot(df[numerical_columns],diag_kind = 'kde')

# %%
sns.boxplot(x='Department',y='Salary',data=df,palette = 'viridis')
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %%
df[numerical_columns].corr()
# Out:
#                         Salary  EmpSatisfaction  SpecialProjectsCount
# Salary                1.000000         0.062718              0.508333  \
# EmpSatisfaction       0.062718         1.000000              0.033877
# SpecialProjectsCount  0.508333         0.033877              1.000000
# EngagementSurvey      0.064966         0.187105              0.013227
# DaysLateLast30       -0.069443        -0.235412             -0.092494
# Absences              0.082382         0.075222             -0.020452
#
#                       EngagementSurvey  DaysLateLast30  Absences
# Salary                        0.064966       -0.069443  0.082382
# EmpSatisfaction               0.187105       -0.235412  0.075222
# SpecialProjectsCount          0.013227       -0.092494 -0.020452
# EngagementSurvey              1.000000       -0.585232 -0.008771
# DaysLateLast30               -0.585232        1.000000  0.001833
# Absences                     -0.008771        0.001833  1.000000
