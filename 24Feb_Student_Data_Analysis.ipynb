# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("student-por.csv")

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher  \
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df['sex'].value_counts()
# Out:
# sex
# F    383
# M    266
# Name: count, dtype: int64

# %%
df['sex'].value_counts().plot.pie(autopct ='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.shape
# Out:
# (649, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.school.unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %% [markdown]
# # i want to make count plot of student for each school

# %%
sns.countplot(x='school',data=df)
# Out:
# <Axes: xlabel='school', ylabel='count'>

# %%
df.age
# Out:
# 0      18
# 1      17
# 2      15
# 3      15
# 4      16
#        ..
# 644    19
# 645    18
# 646    18
# 647    17
# 648    18
# Name: age, Length: 649, dtype: int64

# %%
sns.histplot(df.age,kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df.address.unique()
# Out:
# array(['U', 'R'], dtype=object)

# %%
sns.countplot(x='address',data=df,palette = 'dark')
# Out:
# <Axes: xlabel='address', ylabel='count'>

# %%
df.reason.unique()
# Out:
# array(['course', 'other', 'home', 'reputation'], dtype=object)

# %%
reason_counts = df.reason.value_counts()

# %%
reason_counts
# Out:
# reason
# course        285
# home          149
# reputation    143
# other          72
# Name: count, dtype: int64

# %%
df['reason'].value_counts().plot.pie(autopct='%1.1f%%',labels=)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# insight:
# 1. 43.9% peeople choose school for course

# %%
df['activities'].value_counts()
# Out:
# activities
# no     334
# yes    315
# Name: count, dtype: int64

# %%
df['activities'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# how maany students are weekly alchoholic

# %%
df['Walc'].value_counts()
# Out:
# Walc
# 1    247
# 2    150
# 3    120
# 4     87
# 5     45
# Name: count, dtype: int64

# %%
df['Dalc'].value_counts()
# Out:
# Dalc
# 1    451
# 2    121
# 3     43
# 5     17
# 4     17
# Name: count, dtype: int64

# %%
df.freetime
# Out:
# 0      3
# 1      3
# 2      3
# 3      2
# 4      3
#       ..
# 644    4
# 645    3
# 646    1
# 647    4
# 648    4
# Name: freetime, Length: 649, dtype: int64

# %%
df['absences']
# Out:
# 0      4
# 1      2
# 2      6
# 3      0
# 4      0
#       ..
# 644    4
# 645    4
# 646    6
# 647    6
# 648    4
# Name: absences, Length: 649, dtype: int64

# %%
df['Pstatus'].unique() # parent status A--->away,T--> together
# Out:
# array(['A', 'T'], dtype=object)

# %%
sns.boxplot(data=df,x='Pstatus',y ='absences' )
# Out:
# <Axes: xlabel='Pstatus', ylabel='absences'>

# %%
df.sex.value_counts()
# Out:
# sex
# F    383
# M    266
# Name: count, dtype: int64

# %%
counts = df.Fjob.value_counts()
counts.plot(kind='bar')
# Out:
# <Axes: xlabel='Fjob'>

# %%
counts = df.Mjob.value_counts()
counts.plot(kind='bar',color='g')
# Out:
# <Axes: xlabel='Mjob'>

# %%
df.hist()
#
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'Medu'}>,
#         <Axes: title={'center': 'Fedu'}>,
#         <Axes: title={'center': 'traveltime'}>],
#        [<Axes: title={'center': 'studytime'}>,
#         <Axes: title={'center': 'failures'}>,
#         <Axes: title={'center': 'famrel'}>,
#         <Axes: title={'center': 'freetime'}>],
#        [<Axes: title={'center': 'goout'}>,
#         <Axes: title={'center': 'Dalc'}>,
#         <Axes: title={'center': 'Walc'}>,
#         <Axes: title={'center': 'health'}>],
#        [<Axes: title={'center': 'absences'}>,
#         <Axes: title={'center': 'G1'}>, <Axes: title={'center': 'G2'}>,
#         <Axes: title={'center': 'G3'}>]], dtype=object)

# %%
df.hist(bins=100,figsize=(30,40),color='blue')
plt.show()
# bins-->number of intervals,figsize is paper size

# %%
df.G1.describe()
# Out:
# count    649.000000
# mean      11.399076
# std        2.745265
# min        0.000000
# 25%       10.000000
# 50%       11.000000
# 75%       13.000000
# max       19.000000
# Name: G1, dtype: float64

# %%
df.G1.value_counts()
# Out:
# G1
# 10    95
# 11    91
# 12    82
# 13    72
# 14    71
# 9     65
# 8     42
# 15    35
# 7     33
# 16    22
# 17    16
# 6      9
# 18     7
# 5      5
# 4      2
# 0      1
# 19     1
# Name: count, dtype: int64

# %% [markdown]
# # Bivariate analysis

# %%
# relationship between age and sex
sns.countplot(df,x='age',hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
# pairplot
plt.figure(figsize=(20,10))
sns.pairplot(df)
plt.show()

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %% [markdown]
# # do urban student score higher than rural students

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher  \
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
x = df['address'].value_counts()=='R'
y= df['address'].value_counts()=='U'
# Out:
# address
# U    452
# R    197
# Name: count, dtype: int64

# %%
sns.kdeplot(df.loc[df['address']=='U','G1'],label="Urban",shade=True)
sns.kdeplot(df.loc[df['address']=='R','G1'],label="Rural",shade=True)
plt.title('Performace comresion G1')
plt.xlabel('Grade1')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\vijay\AppData\Local\Temp\ipykernel_7256\768962183.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.loc[df['address']=='U','G1'],label="Urban",shade=True)
# C:\Users\vijay\AppData\Local\Temp\ipykernel_7256\768962183.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.loc[df['address']=='R','G1'],label="Rural",shade=True)
